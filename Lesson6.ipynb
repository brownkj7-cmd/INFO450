# %% [markdown]
# <a href="https://colab.research.google.com/github/brownkj7-cmd/INFO450/blob/main/Lesson6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=""
print(name)
print(bool(name))
bool(0)
bool(7)
# Out:
# False
# True

# %% [markdown]
# If Statement

# %%
x=10
if x>5:
    print("x is greater than 5")
# Out:
# x is greater than 5

# %% [markdown]
# If Else Statment

# %%
x=3
if x>5:
  print("x is greater than 5")
else:
  print("x is less than 5")
# Out:
# x is less than 5

# %%
x=81
if x>90:
  print("a")
elif x>80:
  print("b")
elif x>70:
  print("c")
# Out:
# b

# %% [markdown]
# Logical Operators

# %%
age=25
income=50000
#want to make sure they make 40k a year
if age>18 and income>40000:
  print("congrats twin")
# Out:
# congrats twin

# %%
age=25
income=50000
#want to make sure they make 40k a year
if age>18 and income>40000 or income>400000:
  print("congrats twin")
# Out:
# congrats twin

# %%
hours_worked=40
performance_score=85
tenure=2
if (hours_worked>=40 and performance_score>80) or tenure>=2:
  print("congrats on promotation")
else:
  print("sorry no promotation")
# Out:
# congrats on promotation

# %% [markdown]
# validate conditions

# %%
x=5
y=4
if x==y:
  print("x and y are the same")
else:
  if x<y:
    print("x is smaller")
  else:
    print("y is smaller")
# Out:
# y is smaller

# %%
x=3
y=4
if x==y:
  print("x and y are the same")
else:
  if x<y:
    print("x is smaller")
  else:
    print("y is smaller")
  print("outsideof if stament")
# Out:
# x is smaller
# outsideof if stament

# %%
scores=[80.95,45,78,88]
if min(scores)>60:
  print("passed test")
else:
  print("failed test")
# Out:
# failed test
